# %%
"""
    Here, you can get informatios for each country
"""
# Out:
# '\n    Here, you can get informatios for each country\n'

# %%
# Dependecies

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')

# %%
# Get the dataframe

# Data source: https://gist.github.com/aishwarya8615/89d9f36fc014dea62487f7347864d16a#file-life_expectancy_data-csv

df = pd.read_csv('Life_Expectancy_Data.csv')

# Dropping rows that contain null data

df = df.dropna(axis = 0)

# Dropping rows in the column "Population" in which the content is
# equal to 'Unknown' to avoid conflicts when converting the data from
# Object to numeric

df = df[((df.Population != 'Unknown'))]

# Converting Population from Object to float64

df['Population'] = pd.to_numeric(df['Population'])

df.head()
# Out:
#        Country Continent  Year      Status  Expectancy  Adult_Mortality  \
# 0  Afghanistan      Asia  2015  Developing        65.0              263
# 1  Afghanistan      Asia  2014  Developing        59.9              271
# 2  Afghanistan      Asia  2013  Developing        59.9              268
# 3  Afghanistan      Asia  2012  Developing        59.5              272
# 4  Afghanistan      Asia  2011  Developing        59.2              275
#
#    infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  ...  \
# 0             62     0.01               71.279624         65.0  ...
# 1             64     0.01               73.523582         62.0  ...
# 2             66     0.01               73.219243         64.0  ...
# 3             69     0.01               78.184215         67.0  ...
# 4             71     0.01                7.097109         68.0  ...
#
#    under_five_deaths  Polio  Total_expenditure  Diphtheria   HIV/AIDS  \
# 0                 83    6.0               8.16           65       0.1
# 1                 86   58.0               8.18           62       0.1
# 2                 89   62.0               8.13           64       0.1
# 3                 93   67.0               8.52           67       0.1
# 4                 97   68.0               7.87           68       0.1
#
#              GDP  Population  Thinness_1-19_years  \
# 0     584.259210  33736494.0                 17.2
# 1     612.696514    327582.0                 17.5
# 2     631.744976  31731688.0                 17.7
# 3  669959.000000   3696958.0                 17.9
# 4      63.537231   2978599.0                 18.2
#
#    Income_composition_of_resources  Schooling
# 0                           479.00       10.1
# 1                           476.00       10.0
# 2                             0.47        9.9
# 3                           463.00        9.8
# 4                           454.00        9.5
#
# [5 rows x 22 columns]

# %%
country = ''

print("Of what country do you wanto to see informatios?" )

#country = input()

country
# Out:
# Of what country do you wanto to see informatios?
#  Brazil
# 'Brazil'

# %%
# Function for filtering the DataFrame

country = "Brazil"

def filter_by_country(country):
    return df['Country'] == country

df_country = df.where(filter_by_country(country)).dropna()

df_country
# Out:
#     Country      Continent    Year      Status  Expectancy  Adult_Mortality  \
# 321  Brazil  South America  2014.0  Developing        74.8            144.0
# 322  Brazil  South America  2013.0  Developing        74.7            146.0
# 323  Brazil  South America  2012.0  Developing        74.5            148.0
# 324  Brazil  South America  2011.0  Developing        74.1            152.0
# 325  Brazil  South America  2010.0  Developing        73.8            154.0
# 326  Brazil  South America  2009.0  Developing        73.6            157.0
# 327  Brazil  South America  2008.0  Developing        73.4            158.0
# 328  Brazil  South America  2007.0  Developing        73.3            159.0
# 329  Brazil  South America  2006.0  Developing        73.0            161.0
# 330  Brazil  South America  2005.0  Developing        72.7            163.0
# 331  Brazil  South America  2004.0  Developing        72.0             17.0
# 332  Brazil  South America  2003.0  Developing        71.8            172.0
# 333  Brazil  South America  2002.0  Developing        71.4            176.0
# 334  Brazil  South America  2001.0  Developing        71.0            179.0
# 335  Brazil  South America  2000.0  Developing        75.0            183.0
#
#      infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  ...  \
# 321           44.0     7.32               83.164654         96.0  ...
# 322           46.0     7.24              916.270845         96.0  ...
# 323           49.0     7.55              843.194626         96.0  ...
# 324           51.0     7.58             1084.999766         98.0  ...
# 325           54.0     7.52             1111.191325         96.0  ...
# 326           57.0     7.33              564.523390         99.0  ...
# 327           61.0     7.21              526.378064         96.0  ...
# 328           65.0     7.19              394.932130         99.0  ...
# 329           70.0     7.10               30.303747         99.0  ...
# 330           75.0     6.97               23.763701         98.0  ...
# 331           81.0     6.85              186.609049         96.0  ...
# 332           88.0     6.95               15.857812         97.0  ...
# 333           95.0     7.00              140.982477         92.0  ...
# 334          103.0     7.13              149.480209         91.0  ...
# 335          111.0     7.26              179.477729         94.0  ...
#
#      under_five_deaths  Polio  Total_expenditure  Diphtheria   HIV/AIDS  \
# 321               49.0   96.0               8.32           93       0.1
# 322               52.0   96.0               8.48           97       0.1
# 323               54.0   96.0               8.26           95       0.1
# 324               57.0   98.0               8.90           99       0.1
# 325               61.0   99.0               8.27           99       0.1
# 326               64.0   99.0               8.65           99       0.1
# 327               68.0   99.0               8.24           99       0.1
# 328               73.0   99.0               8.28           99       0.1
# 329               79.0   99.0               8.36           99       0.1
# 330               85.0   99.0               8.27           99       0.1
# 331               93.0   99.0               7.70           99       0.1
# 332              100.0   99.0               6.94           99       0.1
# 333              109.0   99.0               7.13           99       0.1
# 334              118.0   99.0               7.19           98       0.1
# 335              127.0   99.0               7.30           98       0.1
#
#               GDP   Population  Thinness_1-19_years  \
# 321   1226.617310   24213133.0                  2.7
# 322  12216.944600    2248632.0                  2.8
# 323  12291.466850     256983.0                  2.8
# 324  13167.472890  198686688.0                  2.9
# 325  11224.154800  196796269.0                  2.9
# 326   8553.384700  194895996.0                  3.0
# 327   8787.613750   19297929.0                  3.0
# 328   7313.557962   19126637.0                  3.1
# 329    586.145975   18912412.0                  3.1
# 330    477.182746  186917361.0                  3.2
# 331   3623.476670  184738458.0                  3.2
# 332    359.587582  182482149.0                  3.3
# 333   2819.649531    1815121.0                  3.3
# 334   3146.951770    1777567.0                  3.4
# 335   3739.119360  175287587.0                  3.4
#
#      Income_composition_of_resources  Schooling
# 321                           747.00       15.2
# 322                           734.00       14.2
# 323                             0.73       14.2
# 324                           724.00       14.0
# 325                           716.00       13.8
# 326                           714.00       13.8
# 327                           704.00       13.3
# 328                             0.70       13.5
# 329                           698.00       13.8
# 330                           694.00       13.8
# 331                           695.00       14.0
# 332                           699.00       14.8
# 333                           692.00       14.6
# 334                           685.00       14.3
# 335                           677.00       14.1
#
# [15 rows x 22 columns]

# %%
# Get life expectancy for a specific country

# Function for getting a DataFrame with only the information of the selected country

# X as the years and Y as the expectancy
x, y = (df_country['Year'], df_country['Expectancy'])

if(len(y) == 0):
    print("Error: " + country + " not found!")
else:
    #Graph

    plt.figure(figsize=(16, 8))
    
    plt.title("Life expentacy through the years in " + country)

    plt.xlabel("Year")

    plt.ylabel("Age")
    
    plt.plot(x.array, y.array)
    
    plt.show()
